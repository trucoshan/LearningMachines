# %%
import numpy as np
import sys
sys.path.append('../')

# %%
from src import LinearRegression, LoadData

# %%
import os

# %%
os.chdir('C:\\Users\\shant\\Desktop\\Linear_Regression_Model_From_Scratch\\data')

# %%
X_train = np.load('X_train.npy')
y_train = np.load('y_train.npy')

# %%
model = LinearRegression(X_train,y_train,lr=0.001)

# %%
model.fit(optimization='sgd')
# Out:
# Iteration: 0
# Weight Norm 0.3170327303407426 | Cost: 0.25642951490742916
# Converged after 18 iterations.

# %%
X_val = np.load('X_val.npy')
y_val = np.load('y_val.npy')

# %%
y_pred = model.predict(X_val)

# %%
err = model.evaluate(y_val,y_pred)

# %%
for i in err.keys():
    print(f"{i} : {err[i]}")
# Out:
# mse : 0.3513308554531898
# rmse : 0.592731689260149

# %% [markdown]
# **The model is now trained**
